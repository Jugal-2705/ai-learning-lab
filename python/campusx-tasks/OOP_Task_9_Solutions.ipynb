# %% [markdown]
# <a href="https://colab.research.google.com/github/Jugal-2705/ai-learning-lab/blob/main/python/campusx-tasks/OOP_Task_9_Solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### `Problem-1:` Class inheritence
#
# Create a **Bus** child class that inherits from the Vehicle class. The default fare charge of any vehicle is seating capacity * 100. If Vehicle is Bus instance, we need to add an extra 10% on full fare as a maintenance charge. So total fare for bus instance will become the final amount = total fare + 10% of the total fare.
#
# Note: The bus seating capacity is 50. so the final fare amount should be 5500. You need to override the fare() method of a Vehicle class in Bus class.

# %%
class Vehicle:
  def __init__(self,capacity):
    self.farecharge=100
    self.capacity = capacity
  def fare(self):
    print(f"Vehicle farecharge is: {self.capacity*self.farecharge}")
    return self.capacity*self.farecharge

class Bus(Vehicle):
  def fare(self):
    totalfare = super().fare()
    if self.capacity <= 50:
      print(f"Total Bus Fare is: {totalfare+totalfare*0.1}")
    else:
      print("Maximum Capacity Exceeded")

v = Vehicle(4)
v.fare()
b = Bus(50)
b.fare()
b1 = Bus(51)
b1.fare()
# Out:
# Vehicle farecharge is: 400
# Vehicle farecharge is: 5000
# Total Bus Fare is: 5500.0
# Vehicle farecharge is: 5100
# Maximum Capacity Exceeded

# %% [markdown]
# ### `Problem-2:` Class Inheritence
#
# Create a Bus class that inherits from the Vehicle class. Give the capacity argument of *Bus.seating_capacity()* a default value of 50.
#
# Use the following code for your parent Vehicle class.

# %%
class Vehicle:
  def __init__(self,capacity):
    self.farecharge=100
    self.capacity = capacity
  def fare(self):
    print(f"Vehicle farecharge is: {self.capacity*self.farecharge}")
    return self.capacity*self.farecharge

class Bus(Vehicle):
  def fare(self):
      totalfare = super().fare()
      print(f"Total Bus Fare is: {totalfare+totalfare*0.1}")
  def seating_capacity(self,capacity=50):
    print(f"Capacity is: {capacity}")

b = Bus(40)
b.seating_capacity()
b1 = Bus(50)
b1.seating_capacity(70)
# Out:
# Capacity is: 50
# Capacity is: 70

# %% [markdown]
# ### `Problem-3:` Write a program that has a class Point. Define another class Location which has two objects (Location & Destination) of class Point. Also define a function in Location that prints the reflection of Destination on the x axis.

# %%
class Point:
  def __init__(self,x,y):
    self.x = x
    self.y = y
class Location:
  def __init__(self,location,destination):
    self.location = location
    self.destination = destination
  def reflection(self):
    print(f"<{self.destination.x},{-self.destination.y}>")
p1 = Point(1,4)
p2 = Point(5,8)
l = Location(p1,p2)
l.reflection()
# Out:
# <5,-8>

# %% [markdown]
# ### `Problem-4:` Write a program that has an abstract class Polygon. Derive two classes Rectangle and Triamgle from Polygon and write methods to get the details of their dimensions and hence calculate the area.

# %%
from abc import ABC, abstractmethod


class Polygon(ABC):

    @abstractmethod
    def dimensions(self):
        pass

    @abstractmethod
    def area(self):
        pass


class Rectangle(Polygon):

    def __init__(self, length, breadth):
        self.length = length
        self.breadth = breadth

    def dimensions(self):
        print(f"Rectangle Dimensions:")
        print(f"Length = {self.length}")
        print(f"Breadth = {self.breadth}")

    def area(self):
        return self.length * self.breadth


class Triangle(Polygon):

    def __init__(self, base, height):
        self.base = base
        self.height = height

    def dimensions(self):
        print(f"Triangle Dimensions:")
        print(f"Base = {self.base}")
        print(f"Height = {self.height}")

    def area(self):
        return 0.5 * self.base * self.height


# Driver Code
rectangle = Rectangle(3, 6)
rectangle.dimensions()
print(f"Area = {rectangle.area()}")

print()

triangle = Triangle(6, 5)
triangle.dimensions()
print(f"Area = {triangle.area()}")
# Out:
# Rectangle Dimensions:
# Length = 3
# Breadth = 6
# Area = 18
#
# Triangle Dimensions:
# Base = 6
# Height = 5
# Area = 15.0

# %% [markdown]
# ### `Problem-5:` Write a program with class Bill. The users have the option to pay the bill either by cheque or by cash. Use the inheritance to model this situation.

# %%
from abc import ABC, abstractmethod

class Payment(ABC):
    @abstractmethod
    def pay(self, bill_amount):
        pass

class Cash(Payment):

    def __init__(self, amount):
        self.amount = amount

    def pay(self, bill_amount):
        if self.amount >= bill_amount:
            print("Payment successful using Cash")
        else:
            print("Insufficient cash")

class Cheque(Payment):

    def __init__(self, amount):
        self.amount = amount

    def pay(self, bill_amount):
        if self.amount == bill_amount:
            print("Payment successful using Cheque")
        else:
            print("Cheque amount is incorrect")

class Bill:
    def __init__(self, payable_amount):
        self.payable_amount = payable_amount

    def make_payment(self, payment):
        payment.pay(self.payable_amount)


bill = Bill(2500)
cash = Cash(2500)
bill.make_payment(cash)

cheque = Cheque(3000)
bill.make_payment(cheque)
# Out:
# Payment successful using Cash
# Cheque amount is incorrect

# %% [markdown]
# ###`Q-6:` FlexibleDict
# As of now we are accessing values from dictionary with exact keys. Now we want to amend accessing values functionality. if a dict have key `1` (int) the even if we try to access values by giving `'1'` (1 as str) as key, we should get the same result and vice versa.
#
# Write a class `FlexibleDict` upon builtin `dict` class with above required functionality.
#
# Hint- `dict[key] => dict.__getitem__(key)`

# %% [markdown]
# Ex.
# ```
# fd = FlexibleDict()
# fd['a'] = 100
# print(fd['a']) # Like regular dict
#
# fd[5] = 500
# print(fd[5]) # Like regular dict
#
# fd[1] = 100
# print(fd['1']) # actual Key is int but still trying to access through str key.
# fd['1'] = 100
# print(fd[1])
#
# ```
# `Output:`
# ```
# 100
# 500
# 100
# 100
#
# ```

# %%
class FlexibleDict(dict):

  def __getitem__(self, key):

    if key in self:
      return super().__getitem__(key)
    if isinstance(key, int):
      key = str(key)
    elif isinstance(key, str) and key.isdigit():
      key = int(key)
    return super().__getitem__(key)

d={'1':'Jugal', 2:'Mayani', '75': 75}
f = FlexibleDict(d)
print(f[1], f['2'], f[75])
# Out:
# Jugal Mayani 75
